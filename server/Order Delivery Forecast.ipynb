# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data.csv')
df
# Out:
#     dispatching_time  distance  courier_service  origin_city  target_city  \
# 0                  2      2000                3            3            2
# 1                  1      1000                3            3            2
# 2                  2      1500                3            3            3
# 3                  1       750                3            3            3
# 4                  1       800                2            2            3
# 5                  1       835                2            3            2
# 6                  2       920                2            3            2
# 7                  2       750                2            2            3
# 8                  2        50                2            3            2
# 9                  2        60                3            3            2
# 10                 2        20                3            3            3
# 11                 2       250                3            3            3
# ...

# %%
x = np.arange(0,51)
plt.plot(x, df['dispatching_time'], x, df['courier_service'], x, df['target_city'])

# %%
lr_model = LinearRegression()
dt_model = DecisionTreeRegressor()
svmr_model = LinearSVR()
knnr_model = KNeighborsRegressor()
x_train, x_test, y_train, y_test = train_test_split(df[['dispatching_time','distance','courier_service','origin_city','target_city','festive_season']],df['delivery_time'])
lr_model.fit(x_train,y_train)
dt_model.fit(x_train,y_train)
svmr_model.fit(x_train,y_train)
knnr_model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform')

# %%
lr_model.score(x_test,y_test), dt_model.score(x_test,y_test), svmr_model.score(x_test,y_test), knnr_model.score(x_test,y_test)
# Out:
# (0.8525948048200199,
#  0.4194174757281555,
#  0.08756184360733199,
#  0.3240000000000002,
#  0.23076923076923078)

# %% [markdown]
# As you can see we are getting the highest accuracy using Linear Regression Model. That is over 70%-80%.
